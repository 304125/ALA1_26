# %%
from sympy import *
init_printing()
from IPython.display import Math
from sympy import Rational as R

# %% [markdown]
# ## 6.1 Inner Product, Length and Orthogonality

# %%
v = Matrix([1, -2, 2, 0])
v_unit = v / sqrt(v.dot(v))
v_unit
# Out:
# ⎡1/3 ⎤
# ⎢    ⎥
# ⎢-2/3⎥
# ⎢    ⎥
# ⎢2/3 ⎥
# ⎢    ⎥
# ⎣ 0  ⎦

# %% [markdown]
# ## 6.2 Orthogonal Sets

# %%
u1 = Matrix([3, 1, 1])
u2 = Matrix([-1, 2, 1])
u3 = Matrix([-1, -4, 7])
y = Matrix([6, 1, -8])
U = Matrix.hstack(u1, u2, u3)
U.T*U
# Out:
# ⎡11  0  0 ⎤
# ⎢         ⎥
# ⎢0   6  0 ⎥
# ⎢         ⎥
# ⎣0   0  66⎦

# %%
c1 = y.dot(u1) / u1.dot(u1)
c2 = y.dot(u2) / u2.dot(u2)
c3 = y.dot(u3) / u3.dot(u3)
c1, c2, c3
# Out:
# (1, -2, -1)

# %%
y = Matrix([3, R(1,2), -4])
c1 = y.dot(u1) / u1.dot(u1)
c2 = y.dot(u2) / u2.dot(u2)
c3 = y.dot(u3) / u3.dot(u3)
c1, c2, c3
# Out:
# (1/2, -1, -1/2)

# %% [markdown]
# ## 6.3 Orthogonal Projections

# %%
y_bar = Matrix([7, 6])
u_bar = Matrix([4, 2])
y_hat = y_bar.dot(u_bar) / u_bar.dot(u_bar) * u_bar
y_hat
# Out:
# ⎡8⎤
# ⎢ ⎥
# ⎣4⎦

# %%
z_bar = y_bar - y_hat
z_bar
# Out:
# ⎡-1⎤
# ⎢  ⎥
# ⎣2 ⎦

# %%
# check
y_hat.dot(z_bar)
# Out:
# 0

# %%
u1 = Matrix([2, 5, -1])
u2 = Matrix([-2, 1, 1])
y_bar = Matrix([1, 2, 3])

y_hat = y_bar.dot(u1) / u1.dot(u1) * u1 + y_bar.dot(u2) / u2.dot(u2) * u2
y_hat
# Out:
# ⎡-2/5⎤
# ⎢    ⎥
# ⎢ 2  ⎥
# ⎢    ⎥
# ⎣1/5 ⎦

# %%
z_bar = y_bar - y_hat
z_bar
# Out:
# ⎡7/5 ⎤
# ⎢    ⎥
# ⎢ 0  ⎥
# ⎢    ⎥
# ⎣14/5⎦

# %%
# check
y_hat.dot(z_bar)
# Out:
# 0

# %%
# make y_hat and z_bar orthonormal
y_hat_unit = y_hat / sqrt(y_hat.dot(y_hat))
z_bar_unit = z_bar / sqrt(z_bar.dot(z_bar))
y_hat_unit, z_bar_unit
# Out:
# ⎛⎡-2⋅√105 ⎤        ⎞
# ⎜⎢────────⎥  ⎡ √5 ⎤⎟
# ⎜⎢  105   ⎥  ⎢ ── ⎥⎟
# ⎜⎢        ⎥  ⎢ 5  ⎥⎟
# ⎜⎢ 2⋅√105 ⎥  ⎢    ⎥⎟
# ⎜⎢ ────── ⎥, ⎢ 0  ⎥⎟
# ⎜⎢   21   ⎥  ⎢    ⎥⎟
# ⎜⎢        ⎥  ⎢2⋅√5⎥⎟
# ⎜⎢  √105  ⎥  ⎢────⎥⎟
# ⎜⎢  ────  ⎥  ⎣ 5  ⎦⎟
# ⎝⎣  105   ⎦        ⎠

# %% [markdown]
# ## 6.4 The Gram-Schmidt process

# %%
x1 = Matrix([3, 6, 0])
x2 = Matrix([1, 2, 2])

# check for linear independence
A = Matrix.hstack(x1, x2)
A.rref()
# Out:
# ⎛⎡1  0⎤        ⎞
# ⎜⎢    ⎥        ⎟
# ⎜⎢0  1⎥, (0, 1)⎟
# ⎜⎢    ⎥        ⎟
# ⎝⎣0  0⎦        ⎠

# %%
# check for orthogonality (dot product = 0)
x1.dot(x2)
# Out:
# 15

# %%
A.columnspace()
# Out:
# ⎡⎡3⎤  ⎡1⎤⎤
# ⎢⎢ ⎥  ⎢ ⎥⎥
# ⎢⎢6⎥, ⎢2⎥⎥
# ⎢⎢ ⎥  ⎢ ⎥⎥
# ⎣⎣0⎦  ⎣2⎦⎦

# %%
GramSchmidt(A.columnspace())
# Out:
# ⎡⎡3⎤  ⎡0⎤⎤
# ⎢⎢ ⎥  ⎢ ⎥⎥
# ⎢⎢6⎥, ⎢0⎥⎥
# ⎢⎢ ⎥  ⎢ ⎥⎥
# ⎣⎣0⎦  ⎣2⎦⎦

# %%
x1, x2 - x2.project(x1)
# Out:
# ⎛⎡3⎤  ⎡0⎤⎞
# ⎜⎢ ⎥  ⎢ ⎥⎟
# ⎜⎢6⎥, ⎢0⎥⎟
# ⎜⎢ ⎥  ⎢ ⎥⎟
# ⎝⎣0⎦  ⎣2⎦⎠
